# %%
import requests
import json

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.125 Safari/537.36'
}

url = 'https://www.dcard.tw/service/api/v2/forums/photography/posts?limit=30&before=234266135'

res = requests.get(url, headers=headers)

# %%
res.text
# Out:
# '[{"id":234264637,"title":"#作品分享 #基隆","excerpt":"第一次發文，打擾到各位很抱歉。腦袋一陣混亂也不曉得說些什麼比較好，還是其實什麼都不說才是好的？總之，關於坐了很久的火車、潮濕的空氣、一些算是微小而可貴的瞬間，五月的基隆，有時看不清楚才會看得清楚，大概","anonymousSchool":false,"anonymousDepartment":false,"pinned":false,"forumId":"d0cd5819-4627-4b5f-8a8e-050976e0fba1","replyId":null,"createdAt":"2020-08-20T15:49:51.950Z","updatedAt":"2020-08-20T15:49:51.950Z","commentCount":9,"likeCount":19,"withNickname":true,"tags":[],"topics":["作品","人像攝影","單眼","攝影"],"meta":{"layout":"classic"},"forumName":"攝影","forumAlias":"photography","nsfw":false,"gender":"M","school":"想在滾筒洗衣機裡頭旋轉","department":"weclometo_kkk","replyTitle":null,"reportReason":"","mediaMeta":[{"id":"ec12adc0-e716-43ab-8fc7-3c4c83f1da26","url":"https://i.imgur.com/XTmbZgsl.jpg","normalizedUrl":"https://i.imgur.com/XTmbZgsl.jpg","thumbnail":"https://i.imgur.com/XTmbZgsl.jpg","type":"image/thumbnail","tags":["ANNOTATED"],"createdAt":"2020-08-20T15:49:51.950Z","updatedAt":"2020-08-20T15:49:51.950Z"},{"id":"ec12adc0-e716-43ab-8fc7-3c4c
# ...

# %%
article_list = json.loads(res.text)
article_list
# Out:
# [{'id': 234264637,
#   'title': '#作品分享 #基隆',
#   'excerpt': '第一次發文，打擾到各位很抱歉。腦袋一陣混亂也不曉得說些什麼比較好，還是其實什麼都不說才是好的？總之，關於坐了很久的火車、潮濕的空氣、一些算是微小而可貴的瞬間，五月的基隆，有時看不清楚才會看得清楚，大概',
#   'anonymousSchool': False,
#   'anonymousDepartment': False,
#   'pinned': False,
#   'forumId': 'd0cd5819-4627-4b5f-8a8e-050976e0fba1',
#   'replyId': None,
#   'createdAt': '2020-08-20T15:49:51.950Z',
#   'updatedAt': '2020-08-20T15:49:51.950Z',
#   'commentCount': 9,
#   'likeCount': 19,
#   'withNickname': True,
#   'tags': [],
#   'topics': ['作品', '人像攝影', '單眼', '攝影'],
#   'meta': {'layout': 'classic'},
#   'forumName': '攝影',
#   'forumAlias': 'photography',
#   'nsfw': False,
#   'gender': 'M',
#   'school': '想在滾筒洗衣機裡頭旋轉',
#   'department': 'weclometo_kkk',
#   'replyTitle': None,
#   'reportReason': '',
#   'mediaMeta': [{'id': 'ec12adc0-e716-43ab-8fc7-3c4c83f1da26',
#     'url': 'https://i.imgur.com/XTmbZgsl.jpg',
#     'normalizedUrl': 'https://i.imgur.com/XTmbZgsl.jpg',
# ...

# %%
article_list[0]
# Out:
# {'id': 234264637,
#  'title': '#作品分享 #基隆',
#  'excerpt': '第一次發文，打擾到各位很抱歉。腦袋一陣混亂也不曉得說些什麼比較好，還是其實什麼都不說才是好的？總之，關於坐了很久的火車、潮濕的空氣、一些算是微小而可貴的瞬間，五月的基隆，有時看不清楚才會看得清楚，大概',
#  'anonymousSchool': False,
#  'anonymousDepartment': False,
#  'pinned': False,
#  'forumId': 'd0cd5819-4627-4b5f-8a8e-050976e0fba1',
#  'replyId': None,
#  'createdAt': '2020-08-20T15:49:51.950Z',
#  'updatedAt': '2020-08-20T15:49:51.950Z',
#  'commentCount': 9,
#  'likeCount': 19,
#  'withNickname': True,
#  'tags': [],
#  'topics': ['作品', '人像攝影', '單眼', '攝影'],
#  'meta': {'layout': 'classic'},
#  'forumName': '攝影',
#  'forumAlias': 'photography',
#  'nsfw': False,
#  'gender': 'M',
#  'school': '想在滾筒洗衣機裡頭旋轉',
#  'department': 'weclometo_kkk',
#  'replyTitle': None,
#  'reportReason': '',
#  'mediaMeta': [{'id': 'ec12adc0-e716-43ab-8fc7-3c4c83f1da26',
#    'url': 'https://i.imgur.com/XTmbZgsl.jpg',
#    'normalizedUrl': 'https://i.imgur.com/XTmbZgsl.jpg',
#    'thumbnail': 'https://i.imgur.com/XTmbZgsl.jpg',
# ...

# %%
article_list[1]
# Out:
# {'id': 234264506,
#  'title': '#黑白 抽離色彩',
#  'excerpt': '很喜歡黑白照片有層次的明暗對比，抽離了色彩讓我們更專注在照片本身，彷彿可以感受到照片中有著很抽象的情感，望著螢幕中自己拍的黑白照片，看著看著突然有點兒感到孤獨，大家對黑白照片有什麼看法和拍攝建議呢，那',
#  'anonymousSchool': False,
#  'anonymousDepartment': False,
#  'pinned': False,
#  'forumId': 'd0cd5819-4627-4b5f-8a8e-050976e0fba1',
#  'replyId': None,
#  'createdAt': '2020-08-20T15:31:04.734Z',
#  'updatedAt': '2020-08-20T21:06:12.319Z',
#  'commentCount': 3,
#  'likeCount': 6,
#  'withNickname': False,
#  'tags': [],
#  'topics': ['攝影作品', '攝影', '照片', '單眼', '相機'],
#  'meta': {'layout': 'classic'},
#  'forumName': '攝影',
#  'forumAlias': 'photography',
#  'nsfw': False,
#  'gender': 'M',
#  'school': '國立東華大學',
#  'department': '材料科學與工程學系',
#  'replyTitle': None,
#  'reportReason': '',
#  'mediaMeta': [{'id': '980fadc3-d3d8-498a-9402-cb62017eb115',
#    'url': 'https://i.imgur.com/jumiEgxl.jpg',
#    'normalizedUrl': 'https://i.imgur.com/jumiEgxl.jpg',
#    'thumbnail': 'https://i.imgur.com/jumiEgxl.jpg',
# ...

# %%
article_list[1].keys()
# Out:
# dict_keys(['id', 'title', 'excerpt', 'anonymousSchool', 'anonymousDepartment', 'pinned', 'forumId', 'replyId', 'createdAt', 'updatedAt', 'commentCount', 'likeCount', 'withNickname', 'tags', 'topics', 'meta', 'forumName', 'forumAlias', 'nsfw', 'gender', 'school', 'department', 'replyTitle', 'reportReason', 'mediaMeta', 'reactions', 'hidden', 'customStyle', 'isSuspiciousAccount', 'layout', 'categories', 'withImages', 'withVideos', 'media', 'reportReasonText', 'elapsedTime', 'postAvatar'])

# %%
for k in article_list[1]:
    print(k)
# Out:
# id
# title
# excerpt
# anonymousSchool
# anonymousDepartment
# pinned
# forumId
# replyId
# createdAt
# updatedAt
# commentCount
# likeCount
# withNickname
# tags
# topics
# meta
# forumName
# forumAlias
# nsfw
# gender
# school
# department
# replyTitle
# reportReason
# mediaMeta
# reactions
# hidden
# customStyle
# isSuspiciousAccount
# layout
# categories
# withImages
# withVideos
# media
# reportReasonText
# elapsedTime
# postAvatar

# %%
article_list[1]['title']
# Out:
# '#黑白 抽離色彩'

# %%
for article in article_list:
    article_name = article['title']
    article_url = 'https://www.dcard.tw/f/photography/p/' + str(article['id'])
    print(article_name)
    print(article_url)
# Out:
# #作品分享 #基隆
# https://www.dcard.tw/f/photography/p/234264637
# #黑白 抽離色彩
# https://www.dcard.tw/f/photography/p/234264506
# 不知道大家喜不喜歡，黑白的拍攝手法，最近有點愛上黑白攝影，大家一起來看看吧！
# https://www.dcard.tw/f/photography/p/234264359
# 作品分享/旗袍/九份
# https://www.dcard.tw/f/photography/p/234263940
# Lightroom 手機色調不見了
# https://www.dcard.tw/f/photography/p/234263289
# 手機拍攝+內建調色
# https://www.dcard.tw/f/photography/p/234263282
# 作品分享
# https://www.dcard.tw/f/photography/p/234263200
# 台北街景（黑白
# https://www.dcard.tw/f/photography/p/234262993
# 台灣的山 （1）
# https://www.dcard.tw/f/photography/p/234262521
# 17小時！人像創作！（1）
# https://www.dcard.tw/f/photography/p/234262499
# 柴山拍得到銀河嗎？
# https://www.dcard.tw/f/photography/p/234262490
# Lightroom
# https://www.dcard.tw/f/photography/p/234261525
# 有影無影？
# https://www.dcard.tw/f/photography/p/234261188
# #底片 一些我很喜歡的光影
# https://www.dcard.tw/f/photography/p/234260919
# #分享 業餘手機拍攝（墾丁）
# https://www.dcard.tw/f/photography/p/234260814
# #福田式煙火#王功漁火節
# ...

# %%
article_list[1]['withImages']
# Out:
# True

# %%
article_list[1]['mediaMeta']
# Out:
# [{'id': '980fadc3-d3d8-498a-9402-cb62017eb115',
#   'url': 'https://i.imgur.com/jumiEgxl.jpg',
#   'normalizedUrl': 'https://i.imgur.com/jumiEgxl.jpg',
#   'thumbnail': 'https://i.imgur.com/jumiEgxl.jpg',
#   'type': 'image/thumbnail',
#   'tags': ['ANNOTATED'],
#   'createdAt': '2020-08-20T15:31:04.734Z',
#   'updatedAt': '2020-08-20T21:06:12.319Z'},
#  {'id': '980fadc3-d3d8-498a-9402-cb62017eb115',
#   'url': 'https://i.imgur.com/jumiEgx.jpg',
#   'normalizedUrl': 'https://imgur.com/jumiEgx',
#   'thumbnail': 'https://i.imgur.com/jumiEgxl.jpg',
#   'type': 'image/imgur',
#   'tags': ['ANNOTATED'],
#   'createdAt': '2020-08-20T15:31:04.734Z',
#   'updatedAt': '2020-08-20T21:06:12.319Z'},
#  {'id': '26a69961-2577-4232-9983-26fe53920fa3',
#   'url': 'https://i.imgur.com/scsmuMr.jpg',
#   'normalizedUrl': 'https://imgur.com/scsmuMr',
#   'thumbnail': 'https://i.imgur.com/scsmuMrl.jpg',
#   'type': 'image/imgur',
#   'tags': ['ANNOTATED'],
#   'createdAt': '2020-08-20T15:31:04.734Z',
# ...

# %%
for article in article_list:
    article_name = article['title']
    article_url = 'https://www.dcard.tw/f/photography/p/' + str(article['id'])
    print(article_name)
    print(article_url)
    img_list = article['mediaMeta']
    for img in img_list:
        url_img = img['url']
        print('\t', url_img)
# Out:
# #作品分享 #基隆
# https://www.dcard.tw/f/photography/p/234264637
# 	 https://i.imgur.com/XTmbZgsl.jpg
# 	 https://i.imgur.com/XTmbZgs.jpg
# 	 https://i.imgur.com/2HPCjEj.jpg
# 	 https://i.imgur.com/sehhGgw.jpg
# 	 https://i.imgur.com/yZuXUfP.jpg
# 	 https://i.imgur.com/Sm8xK3I.jpg
# #黑白 抽離色彩
# https://www.dcard.tw/f/photography/p/234264506
# 	 https://i.imgur.com/jumiEgxl.jpg
# 	 https://i.imgur.com/jumiEgx.jpg
# 	 https://i.imgur.com/scsmuMr.jpg
# 	 https://i.imgur.com/HUZE1YO.jpg
# 	 https://i.imgur.com/hMQDUEH.jpg
# 	 https://i.imgur.com/Duu1TjT.jpg
# 	 https://i.imgur.com/dJoDTfo.jpg
# 不知道大家喜不喜歡，黑白的拍攝手法，最近有點愛上黑白攝影，大家一起來看看吧！
# https://www.dcard.tw/f/photography/p/234264359
# 	 https://i.imgur.com/CR4kweul.jpg
# 	 https://i.imgur.com/CR4kweu.jpg
# 	 https://i.imgur.com/l4Zmg8m.jpg
# 	 https://i.imgur.com/6gmwBZ9.jpg
# 	 https://i.imgur.com/7BJRVws.jpg
# 	 https://i.imgur.com/n4HK49B.jpg
# 	 https://i.imgur.com/HbcW8Dl.jpg
# 	 https://i.imgur.com/ALOTBmD.jpg
# ...

# %%
import requests
import json
from urllib import request
import ssl
import os
ssl._create_default_https_context = ssl._create_unverified_context

headers = {
    'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.125 Safari/537.36'
}

url = 'https://www.dcard.tw/service/api/v2/forums/photography/posts?limit=30&before=234266135'

res = requests.get(url, headers=headers)

# %%
try:
    os.mkdir('./dcard_photo')
except:
    pass

for article in article_list:
    article_name = article['title']
    article_url = 'https://www.dcard.tw/f/photography/p/' + str(article['id'])
    print(article_name)
    print(article_url)
    img_list = article['mediaMeta']
    for img in img_list:
        url_img = img['url']
        img_path = './dcard_photo/' + url_img.split('/')[-1]  # XTmbZgsl.jpg
        print('\t', url_img)
#         request.urlretrieve(url_img, img_path)
        res_img = requests.get(url_img, headers=headers)
        img_source = res_img.content
        with open(img_path, 'wb') as f:
            f.write(img_source)
# Out:
# #作品分享 #基隆
# https://www.dcard.tw/f/photography/p/234264637
# 	 https://i.imgur.com/XTmbZgsl.jpg
# 	 https://i.imgur.com/XTmbZgs.jpg
# 	 https://i.imgur.com/2HPCjEj.jpg
# 	 https://i.imgur.com/sehhGgw.jpg
# 	 https://i.imgur.com/yZuXUfP.jpg
# 	 https://i.imgur.com/Sm8xK3I.jpg
# #黑白 抽離色彩
# https://www.dcard.tw/f/photography/p/234264506
# 	 https://i.imgur.com/jumiEgxl.jpg
# 	 https://i.imgur.com/jumiEgx.jpg
# 	 https://i.imgur.com/scsmuMr.jpg
# 	 https://i.imgur.com/HUZE1YO.jpg
# 	 https://i.imgur.com/hMQDUEH.jpg
# 	 https://i.imgur.com/Duu1TjT.jpg
# 	 https://i.imgur.com/dJoDTfo.jpg
# 不知道大家喜不喜歡，黑白的拍攝手法，最近有點愛上黑白攝影，大家一起來看看吧！
# https://www.dcard.tw/f/photography/p/234264359
# 	 https://i.imgur.com/CR4kweul.jpg
# 	 https://i.imgur.com/CR4kweu.jpg
# 	 https://i.imgur.com/l4Zmg8m.jpg
# 	 https://i.imgur.com/6gmwBZ9.jpg
# 	 https://i.imgur.com/7BJRVws.jpg
# 	 https://i.imgur.com/n4HK49B.jpg
# 	 https://i.imgur.com/HbcW8Dl.jpg
# 	 https://i.imgur.com/ALOTBmD.jpg
# ...
